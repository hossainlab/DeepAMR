# %%
import numpy as np 
import pandas as pd

# %%
pd.read_csv("../data/raw/ncbi/complete_metadata.csv")
# Out:
#     biosample_id       accession               organism        strain  \
# 0       54875024    SAMN54875024                    NaN  PNUSAE221323
# 1       54875022    SAMN54875022                    NaN  PNUSAE221322
# 2       54875019    SAMN54875019                    NaN  PNUSAE221320
# 3       54874631    SAMN54874631                    NaN  PNUSAE221325
# 4       54874628    SAMN54874628                    NaN  PNUSAE221321
# 5       54853498  SAMEA120970212  Klebsiella pneumoniae           NaN
# 6       54832029  SAMEA120970146  Klebsiella pneumoniae           NaN
# 7       54821146  SAMEA120970149  Klebsiella pneumoniae           NaN
# 8       54815314  SAMEA120969541  Klebsiella pneumoniae           NaN
# 9       54872776    SAMN54872776                    NaN           NaN
# 10      54875861    SAMN54875861                    NaN           NaN
# 11      54875860    SAMN54875860                    NaN           NaN
# ...

# %%
pd.read_csv("../data/raw/patric/genomes_metadata.csv")
# Out:
#      assembly_accession bioproject_accession biosample_accession cell_shape  \
# 0       GCA_000184185.1           PRJNA48011        SAMN02602978    Bacilli
# 1       GCA_000184185.1           PRJNA48011        SAMN02602978    Bacilli
# 2                   NaN                  NaN                 NaN        NaN
# 3       GCA_000027125.1           PRJEA40647        SAMEA2272277    Bacilli
# 4       GCA_000529855.1            PRJEB4814        SAMEA3138867        NaN
# ...                 ...                  ...                 ...        ...
# 1995    GCA_020254765.1          PRJNA766794        SAMN21876336        NaN
# 1996    GCA_020254845.1          PRJNA766794        SAMN21876331        NaN
# 1997    GCA_020254905.1          PRJNA766794        SAMN21876374        NaN
# 1998    GCA_020254945.1          PRJNA766794        SAMN21876363        NaN
# 1999    GCA_020255105.1          PRJNA766794        SAMN21876378        NaN
#
# ...
